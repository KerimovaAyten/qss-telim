# %% [markdown]
# ### 1. Suppose you know x is integer, ys is a string representing integer. For instance, x is 3 and ys is ‘24’. Write code to print out arithmetic sum of x and ys.

# %%
x=3
ys="24"

# %% [markdown]
# ### 2.Import pandas and read Salaries.csv file

# %%
import pandas as pd
df=pd.read_csv('Salaries.csv')
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# ### 3.What is the name of 3rd column?

# %%
cols=df.columns
cols[2]
# Out:
# 'JobTitle'

# %% [markdown]
# ### 4.View only the columns BasePay and OvertimePay assign them to a dataframe called discipline and sort the teams by Basepay, then to OvertimePay

# %%
df1=df.sort_values(["BasePay","OvertimePay"])
print(df1)
# Out:
#             Id         EmployeeName       JobTitle  BasePay  OvertimePay  \
# 72832    72833       Irwin Sidharta   Junior Clerk  -166.01       249.02
# 72865    72866         Robert Scott   Junior Clerk  -121.63       182.70
# 72872    72873      Chung Huey Kung   Junior Clerk  -109.22       163.83
# 72874    72875            Jordan Li   Junior Clerk  -106.60       159.90
# 72878    72879      Richard Jackson   Junior Clerk  -101.88       153.08
# ...        ...                  ...            ...      ...          ...
# 109246  109247  Cristina  Santillan  Special Nurse      NaN      1730.93
# 148646  148647         Not provided   Not provided      NaN          NaN
# 148650  148651         Not provided   Not provided      NaN          NaN
# 148651  148652         Not provided   Not provided      NaN          NaN
# 148652  148653         Not provided   Not provided      NaN          NaN
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# ...

# %% [markdown]
# ### 5.Filter Players, those OvertimePay is over 60000

# %%
df2=df[df["OvertimePay"]>60000]
df2
# Out:
#             Id    EmployeeName  \
# 1            2    GARY JIMENEZ
# 2            3  ALBERT PARDINI
# 6            7       ALSON LEE
# 8            9  MICHAEL MORRIS
# 10          11   ARTHUR KENNEY
# ...        ...             ...
# 116978  116979       Joe Gauci
# 117217  117218      Chui S Lee
# 117323  117324     Lok Man Lam
# 117512  117513    Lawrence Lee
# 119607  119608   Hung V Nguyen
#
#                                                 JobTitle    BasePay  \
# 1                        CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 6                     BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 8                     BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# ...                                                  ...        ...
# 116978                             Maintenance Machinist   67079.97
# ...

# %% [markdown]
# ### 6.Select the teams from 555 row to 566.

# %%
df3=df.loc[555:566]
df3
# Out:
#       Id      EmployeeName                          JobTitle    BasePay  \
# 555  556       JOHN FLORES                       FIREFIGHTER  105934.65
# 556  557    ALBERT CENDANA       SENIOR PHYSICIAN SPECIALIST  155013.00
# 557  558     MICHAEL BELLO         CAPTAIN, FIRE SUPPRESSION  140546.86
# 558  559  KEVIN LABANOWSKI  SERGEANT III (POLICE DEPARTMENT)  130457.89
# 559  560    STEVEN WOZNIAK       SENIOR PHYSICIAN SPECIALIST  175170.24
# 560  561    KATHRYN FOWLER                     NURSE MANAGER  152743.07
# 561  562     JOSEPH MAYERS                POLICE OFFICER III   67817.57
# 562  563  JOSHUA BAMBERGER       SENIOR PHYSICIAN SPECIALIST  183754.57
# 563  564      MAGALY SAADE                       FIREFIGHTER  105934.68
# 564  565     ELISA RAMIREZ                     NURSE MANAGER  170596.03
# 565  566      BRADEN WOODS        ASSISTANT CHIEF ATTORNEY I  183653.74
# 566  567         JACK CHOW                       FIREFIGHTER  105934.66
#
# ...

# %% [markdown]
# ### 7.What was the average (mean) BasePay of all employees per year? (2011-2014) ?

# %%
import numpy as np
mean=np.mean(df.BasePay)
mean
# Out:
# 66325.44884050643

# %% [markdown]
# ### 8.How many unique job titles are there?

# %%
df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %% [markdown]
# ### 9.How many Job Titles were represented by only one person in 2013?

# %%
# %matplotlib inline
sns.countplot(x='EmployeeName',data=df)

# %% [markdown]
# ### 10.Find correlation between variables.

# %%
df.corr()
# Out:
#                         Id   BasePay  OvertimePay  OtherPay  Benefits  \
# Id                1.000000 -0.204878    -0.081505 -0.100403 -0.348957
# BasePay          -0.204878  1.000000     0.266740  0.285655  0.918028
# OvertimePay      -0.081505  0.266740     1.000000  0.316592  0.301207
# OtherPay         -0.100403  0.285655     0.316592  1.000000  0.233178
# Benefits         -0.348957  0.918028     0.301207  0.233178  1.000000
# TotalPay         -0.211478  0.954494     0.504859  0.470496  0.884097
# TotalPayBenefits -0.092190  0.946595     0.467981  0.422341  0.930140
# Year              0.968171  0.033751     0.027887 -0.002499 -0.043136
# Notes                  NaN       NaN          NaN       NaN       NaN
# Status                 NaN       NaN          NaN       NaN       NaN
#
#                   TotalPay  TotalPayBenefits      Year  Notes  Status
# Id               -0.211478         -0.092190  0.968171    NaN     NaN
# ...

# %% [markdown]
# ### 11. Display relationship between OvertimePay and BasePay
# * Use scatter in matplotlib

# %%
import matplotlib.pyplot as plt
plt.scatter(df['OvertimePay'],df['BasePay'])
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### 12. Show distributions and scatters between all variables

# %%
sns.pairplot(df)

# %% [markdown]
# ### 13.Construct BasePay distribution with title and figsize.(use distplot)

# %%
import seaborn as sns
sns.distplot(df['BasePay'])
import matplotlib.pyplot as plt
plt.title("Displot")
f,ax=plt.subplots(figsize = (18,18))

# %% [markdown]
# ### 14.Find linear relationship between BasePay and OvertimePay for each year.(use lmplot)

# %%
sns.lmplot(x='BasePay',y='OvertimePay',data=df)

# %% [markdown]
# ### 15.Construct heatmap correlation matrix.

# %%
f,ax=plt.subplots(figsize = (18,18))
sns.heatmap(df.corr(),annot= True,linewidths=0.5,fmt = ".1f")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Correlation Map')
plt.savefig('graph.png')
plt.show()
